# %% [markdown]
# ### Task 1

# %% [markdown]
# ![Screen%20Shot%202022-03-08%20at%206.20.19%20PM.png](attachment:Screen%20Shot%202022-03-08%20at%206.20.19%20PM.png)

# %% [markdown]
# ### Task 2

# %%
import numpy as np
import scipy.stats as sts
import matplotlib.pyplot as plt

# %%
# hyperparameters and metadata
num_players = 3
num_games = 4
alpha = 1
beta = 1

players = range(numPlayers)
games = range(numGames)

# %%
field_goal_rates = list()
num_attempts = np.full((num_players,num_games),20)
num_goals = np.zeros((num_players,num_games),dtype=int)

for i in players:
    field_goal_rates.append(sts.beta.rvs(a=alpha,b=beta))
    for j in games:
        num_goals[i][j] = sts.binom.rvs(n=num_attempts[i][j],p=field_goal_rates[i])
print(field_goal_rates)
print(num_goals)
# Out:
# [0.8767159945649677, 0.469592976324692, 0.08187209951970176]
# [[19 17 19 18]
#  [10 11  9  6]
#  [ 0  1  2  1]]
